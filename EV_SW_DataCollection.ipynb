# %% [markdown]
# <a href="https://colab.research.google.com/github/BFvandy/EV_Buzz_Analysis/blob/main/EV_SW_DataCollection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
cur_path = "/content/drive/My Drive/EV Buzz Analysis/Strategic Window Verbatim/Separate Data Files"
os.chdir(cur_path)
# !pwd
# Out:
# /content/drive/My Drive/EV Buzz Analysis/Strategic Window Verbatim/Separate Data Files

# %%
ev_2022_sw = pd.read_csv('EV_2022_SW.csv', skiprows=12)
ev_2021_sw = pd.read_csv('EV_2021_SW.csv', skiprows=12)
ev_2020_sw = pd.read_csv('EV_2020_SW.csv', skiprows=12)

# %%
frames = [ev_2022_sw, ev_2021_sw, ev_2020_sw]
ev_sw = pd.concat(frames)

# %%
ev_sw = ev_sw.reset_index(drop=True)

# %%
ev_sw
# Out:
#                  Purchased  Purchased Year                        Disposed  \
# 0       Nissan Leaf S Plus            2022                          (None)
# 1      Volkswagen ID.4 AWD            2021               BMW X3 xDrive 30e
# 2            Tesla Model 3            2022                          (None)
# 3      Volkswagen ID.4 AWD            2021                     Toyota RAV4
# 4            Tesla Model 3            2022                   Nissan Maxima
# ...                    ...             ...                             ...
# 22511        Tesla Model 3            2020  Volkswagen Passat / New Passat
# 22512    Chevrolet Bolt EV            2020                      GMC Acadia
# 22513  Nissan Leaf SV Plus            2019                 Volvo S60 Sedan
# 22514    Chevrolet Bolt EV            2020               Chevrolet Bolt EV
# 22515  Nissan Leaf SV Plus            2019                    Jeep Patriot
#
# ...

# %%
ev_sw.groupby(['Purchased']).count()
# Out:
#                           Purchased Year   Disposed  Disposed Model Year  \
# Purchased
# Chevrolet Bolt EV                   1887       1887                 1303
# Ford Mustang Mach-E AWD             1176       1176                  800
# Ford Mustang Mach-E RWD              529        529                  366
# GMC Hummer Pickup                     11         11                    1
# Hyundai Ioniq 5 AWD                  250        250                  182
# Hyundai Ioniq 5 RWD                  224        224                  162
# Hyundai Kona EV Limited              537        537                  367
# Hyundai Kona EV SEL                  471        471                  326
# Hyundai Kona EV Ultimate             476        476                  348
# Kia EV6 AWD                          438        438                  320
# Kia EV6 RWD                           90         90                   62
# Nissan Leaf S                        551        551                  282
# ...

# %%
import os
cur_path = "/content/drive/My Drive/EV Buzz Analysis/Strategic Window Verbatim"
os.chdir(cur_path)
# !pwd
# Out:
# /content/drive/My Drive/EV Buzz Analysis/Strategic Window Verbatim

# %%
ev_sw.to_csv('EV_SW_3yrs.csv', index = 'False')
